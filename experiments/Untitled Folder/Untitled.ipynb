# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import seaborn as sns
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/FazlyRabbiBD/Data-Science-Book/master/data-dhaka-weather1953-2016.csv'
df = pd.read_csv(url)

# %%
df.head(10)
# Out:
#    YEAR  Month  MaxTemp  MinTemp  RelativeHumidity  Rainfall
# 0  1953      1     26.7     10.9                70      10.0
# 1  1953      2     33.6     14.7                65       2.0
# 2  1953      3     37.5     21.7                73      90.0
# 3  1953      4     37.7     23.4                69      90.0
# 4  1953      5     34.7     24.2                81     274.0
# 5  1953      6     34.1     25.1                87     333.0
# 6  1953      7     34.8     25.4                89     392.0
# 7  1953      8     32.9     25.7                86     326.0
# 8  1953      9     33.8     25.5                87     352.0
# 9  1953     10     32.3     22.9                80      52.0

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.describe()
# Out:
#               YEAR       Month     MaxTemp    MinTemp  RelativeHumidity  \
# count   768.000000  768.000000  768.000000  768.00000        768.000000
# mean   1984.500000    6.500000   33.438529   21.51875         75.207031
# std      18.484992    3.454302    2.964510    4.97461          8.593081
# min    1953.000000    1.000000   24.300000    9.50000         49.000000
# 25%    1968.750000    3.750000   31.875000   17.15000         69.000000
# 50%    1984.500000    6.500000   33.900000   23.70000         76.000000
# 75%    2000.250000    9.250000   35.525000   25.80000         83.000000
# max    2016.000000   12.000000   40.800000   28.10000         90.000000
#
#          Rainfall
# count  768.000000
# mean   168.377214
# std    173.784463
# min      0.000000
# 25%     13.000000
# 50%    121.000000
# 75%    273.250000
# max    856.000000

# %%
df.corr()
# Out:
#                           YEAR         Month   MaxTemp   MinTemp  \
# YEAR              1.000000e+00  7.480458e-16  0.044080  0.098500
# Month             7.480458e-16  1.000000e+00 -0.134986  0.210387
# MaxTemp           4.407971e-02 -1.349862e-01  1.000000  0.724186
# MinTemp           9.849999e-02  2.103873e-01  0.724186  1.000000
# RelativeHumidity -1.650420e-01  4.810704e-01  0.097398  0.624770
# Rainfall         -9.006300e-03  1.259665e-01  0.365135  0.687317
#
#                   RelativeHumidity  Rainfall
# YEAR                     -0.165042 -0.009006
# Month                     0.481070  0.125966
# MaxTemp                   0.097398  0.365135
# MinTemp                   0.624770  0.687317
# RelativeHumidity          1.000000  0.708577
# Rainfall                  0.708577  1.000000

# %%
correlation = df.corr()
plt.figure(figsize=(16, 8))
sns.heatmap(correlation, annot=True, linewidths=0, vmin=-1, cmap='RdBu_r')
plt.show()

# %%
rain = df.groupby('Month')['Rainfall'].mean()
rain
# Out:
# Month
# 1       6.781250
# 2      19.703125
# 3      54.307812
# 4     126.431250
# 5     271.131250
# 6     360.075000
# 7     382.076563
# 8     313.971875
# 9     284.639063
# 10    164.120313
# 11     28.017187
# 12      9.271875
# Name: Rainfall, dtype: float64

# %%
df.groupby('YEAR')[['MaxTemp', 'MinTemp']].mean()
# Out:
#         MaxTemp    MinTemp
# YEAR
# 1953  33.150000  20.866667
# 1954  33.208333  20.633333
# 1955  32.866667  20.516667
# 1956  32.766667  20.825000
# 1957  33.316667  20.650000
# ...         ...        ...
# 2012  34.116667  22.250000
# 2013  34.175000  22.191667
# 2014  31.133333  22.241667
# 2015  30.865000  22.216667
# 2016  31.692500  23.058333
#
# [64 rows x 2 columns]

# %%
sns.distplot(rain)
# Out:
# C:\Users\mash\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rainfall', ylabel='Density'>
